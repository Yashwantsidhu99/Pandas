# %%
# answer 1
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv('C:/Users/yashw/Downloads/2. Pandas Basic Exercises/Exercise Data Files/Pandas Exercise Lambda Functions Files/student-mat.csv')

# %%
df1
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
df2=pd.read_csv('C:/Users/yashw/Downloads/2. Pandas Basic Exercises/Exercise Data Files/Pandas Exercise Lambda Functions Files/student-por.csv')

# %%
df2
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
# answer 2 and 3
df=df1.merge(df2,on='school',how='outer')
df
# Out:
#        school sex_x  age_x address_x famsize_x Pstatus_x  Medu_x  Fedu_x  \
# 0          GP     F     18         U       GT3         A       4       4
# 1          GP     F     18         U       GT3         A       4       4
# 2          GP     F     18         U       GT3         A       4       4
# 3          GP     F     18         U       GT3         A       4       4
# 4          GP     F     18         U       GT3         A       4       4
# ...       ...   ...    ...       ...       ...       ...     ...     ...
# 158018     MS     M     19         U       LE3         T       1       1
# 158019     MS     M     19         U       LE3         T       1       1
# 158020     MS     M     19         U       LE3         T       1       1
# 158021     MS     M     19         U       LE3         T       1       1
# 158022     MS     M     19         U       LE3         T       1       1
#
#          Mjob_x   Fjob_x  ... famrel_y freetime_y  goout_y  Dalc_y  Walc_y  \
# ...

# %%
df1.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df1[['school','guardian']]
# Out:
#     school guardian
# 0       GP   mother
# 1       GP   father
# 2       GP   mother
# 3       GP   mother
# 4       GP   father
# ..     ...      ...
# 390     MS    other
# 391     MS   mother
# 392     MS    other
# 393     MS   mother
# 394     MS   father
#
# [395 rows x 2 columns]

# %%
da=df.iloc[:,0:12]
da
# Out:
#        school sex_x  age_x address_x famsize_x Pstatus_x  Medu_x  Fedu_x  \
# 0          GP     F     18         U       GT3         A       4       4
# 1          GP     F     18         U       GT3         A       4       4
# 2          GP     F     18         U       GT3         A       4       4
# 3          GP     F     18         U       GT3         A       4       4
# 4          GP     F     18         U       GT3         A       4       4
# ...       ...   ...    ...       ...       ...       ...     ...     ...
# 158018     MS     M     19         U       LE3         T       1       1
# 158019     MS     M     19         U       LE3         T       1       1
# 158020     MS     M     19         U       LE3         T       1       1
# 158021     MS     M     19         U       LE3         T       1       1
# 158022     MS     M     19         U       LE3         T       1       1
#
#          Mjob_x   Fjob_x reason_x guardian_x
# 0       at_home  teacher   course     mother
# ...

# %%
# answer 5
df1.apply(lambda x: x.astype(str).str.upper())
# Out:
#     school sex age address famsize Pstatus Medu Fedu      Mjob      Fjob  ...  \
# 0       GP   F  18       U     GT3       A    4    4   AT_HOME   TEACHER  ...
# 1       GP   F  17       U     GT3       T    1    1   AT_HOME     OTHER  ...
# 2       GP   F  15       U     LE3       T    1    1   AT_HOME     OTHER  ...
# 3       GP   F  15       U     GT3       T    4    2    HEALTH  SERVICES  ...
# 4       GP   F  16       U     GT3       T    3    3     OTHER     OTHER  ...
# ..     ...  ..  ..     ...     ...     ...  ...  ...       ...       ...  ...
# 390     MS   M  20       U     LE3       A    2    2  SERVICES  SERVICES  ...
# 391     MS   M  17       U     LE3       T    3    1  SERVICES  SERVICES  ...
# 392     MS   M  21       R     GT3       T    1    1     OTHER     OTHER  ...
# 393     MS   M  18       R     LE3       T    3    2  SERVICES     OTHER  ...
# 394     MS   M  19       U     LE3       T    1    1     OTHER   AT_HOME  ...
#
# ...

# %%
# answer 6
df['FJOB']=df['Fjob_x'].apply(lambda x:x.upper())
df['MJOB']=df['Mjob_x'].apply(lambda x:x.upper())

# %%
df
# Out:
#        school sex_x  age_x address_x famsize_x Pstatus_x  Medu_x  Fedu_x  \
# 0          GP     F     18         U       GT3         A       4       4
# 1          GP     F     18         U       GT3         A       4       4
# 2          GP     F     18         U       GT3         A       4       4
# 3          GP     F     18         U       GT3         A       4       4
# 4          GP     F     18         U       GT3         A       4       4
# ...       ...   ...    ...       ...       ...       ...     ...     ...
# 158018     MS     M     19         U       LE3         T       1       1
# 158019     MS     M     19         U       LE3         T       1       1
# 158020     MS     M     19         U       LE3         T       1       1
# 158021     MS     M     19         U       LE3         T       1       1
# 158022     MS     M     19         U       LE3         T       1       1
#
#          Mjob_x   Fjob_x  ... goout_y Dalc_y  Walc_y  health_y  absences_y  \
# ...

# %%
# answer 7
df1.tail(10)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 385     MS   F   18       R     GT3       T     2     2   at_home     other
# 386     MS   F   18       R     GT3       T     4     4   teacher   at_home
# 387     MS   F   19       R     GT3       T     2     3  services     other
# 388     MS   F   18       U     LE3       T     3     1   teacher  services
# 389     MS   F   18       U     GT3       T     1     1     other     other
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# ...

# %%
# answer 8
df1['FJOB']=df1['Fjob'].apply(lambda x: x.upper())
df1['MJOB']=df1['Mjob'].apply(lambda x: x.upper())

# %%
df1
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df
# Out:
#        school sex_x  age_x address_x famsize_x Pstatus_x  Medu_x  Fedu_x  \
# 0          GP     F     18         U       GT3         A       4       4
# 1          GP     F     18         U       GT3         A       4       4
# 2          GP     F     18         U       GT3         A       4       4
# 3          GP     F     18         U       GT3         A       4       4
# 4          GP     F     18         U       GT3         A       4       4
# ...       ...   ...    ...       ...       ...       ...     ...     ...
# 158018     MS     M     19         U       LE3         T       1       1
# 158019     MS     M     19         U       LE3         T       1       1
# 158020     MS     M     19         U       LE3         T       1       1
# 158021     MS     M     19         U       LE3         T       1       1
# 158022     MS     M     19         U       LE3         T       1       1
#
#          Mjob_x   Fjob_x  ... goout_y Dalc_y  Walc_y  health_y  absences_y  \
# ...

# %%
# answer 9
def majority():
    df1['Legal Drinker']=df1['age'].apply(lambda x:True if(x>18) else False)
majority()

# %%
df1['Legal Drinker']
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 390     True
# 391    False
# 392     True
# 393    False
# 394     True
# Name: Legal Drinker, Length: 395, dtype: bool

# %%
df1
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df1
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 36 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   school         395 non-null    object
#  1   sex            395 non-null    object
#  2   age            395 non-null    int64
#  3   address        395 non-null    object
#  4   famsize        395 non-null    object
#  5   Pstatus        395 non-null    object
#  6   Medu           395 non-null    int64
#  7   Fedu           395 non-null    int64
#  8   Mjob           395 non-null    object
#  9   Fjob           395 non-null    object
#  10  reason         395 non-null    object
#  11  guardian       395 non-null    object
#  12  traveltime     395 non-null    int64
#  13  studytime      395 non-null    int64
#  14  failures       395 non-null    int64
#  15  schoolsup      395 non-null    object
#  16  famsup         395 non-null    object
# ...

# %%
# answer 10
df1.select_dtypes(include=[np.number])*18
# Out:
#      age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0    324    72    72          36         36         0      72        54
# 1    306    18    18          18         36         0      90        54
# 2    270    18    18          18         36        54      72        54
# 3    270    72    36          18         54         0      54        36
# 4    288    54    54          18         36         0      72        54
# ..   ...   ...   ...         ...        ...       ...     ...       ...
# 390  360    36    36          18         36        36      90        90
# 391  306    54    18          36         18         0      36        72
# 392  378    18    18          18         18        54      90        90
# 393  324    54    36          54         18         0      72        72
# 394  342    18    18          18         18         0      54        36
#
#      goout  Dalc  Walc  health  absences   G1   G2   G3
# ...
