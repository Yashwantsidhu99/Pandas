# %% [markdown]
# # Collaborated with Harsh Manhas

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:/Users/yashw/Downloads/diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
a=df.iloc[np.where(df['Glucose']>125 )]

# %%
a.iloc[np.where(a['Outcome']==0)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 12            10      139             80              0        0  27.1
# 20             3      126             88             41      235  39.3
# 28            13      145             82             19      110  22.2
# 36            11      138             76              0        0  33.2
# 40             3      180             64             25       70  34.0
# ..           ...      ...            ...            ...      ...   ...
# 727            0      141             84             26        0  32.4
# 728            2      175             88              0        0  22.9
# 736            0      126             86             27      120  27.4
# 744           13      153             88             37      140  40.6
# 756            7      137             90             41        0  32.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 12                      1.441   57        0
# 20                      0.704   27        0
# 28                      0.245   57        0
# 36                      0.420   35        0
# 40                      0.271   26        0
# ..                        ...  ...      ...
# 727                     0.433   22        0
# 728                     0.326   22        0
# 736                     0.515   21        0
# 744                     1.174   39        0
# 756                     0.391   39        0
#
# [121 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df['BMI']
# Out:
# 0      33.6
# 1      26.6
# 2      23.3
# 3      28.1
# 4      43.1
#        ...
# 763    32.9
# 764    36.8
# 765    26.2
# 766    30.1
# 767    30.4
# Name: BMI, Length: 768, dtype: float64

# %%
sns.relplot(x='Age',y='Pregnancies',data=df)

# %%
s=df.groupby(['BMI'])['SkinThickness'].max()

# %%
s=pd.DataFrame(s)

# %%
# Insight 1
sns.relplot(kind='scatter',x='BMI',y='SkinThickness',data=s)

# %%
x=df.groupby(['Age'])['Pregnancies'].max()
x=x.sort_values()

# %%
x=x.tail(27)
x=x.sort_values()
x=pd.DataFrame(x)

# %%
# Insight 2
sns.relplot(kind='line',x='Age',y='Pregnancies',data=x)

# %%
# Insight 3
q=df.iloc[np.where(df['Age']<30)]
q.iloc[np.where(q['Outcome']==1)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 6              3       78             50             32       88  31.0
# 23             9      119             80             35        0  29.0
# 31             3      158             76             36      245  31.6
# 38             2       90             68             42        0  38.2
# 45             0      180             66             39        0  42.0
# ..           ...      ...            ...            ...      ...   ...
# 731            8      120             86              0        0  28.4
# 732            2      174             88             37      120  44.5
# 746            1      147             94             41        0  49.3
# 750            4      136             70              0        0  31.2
# 753            0      181             88             44      510  43.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 6                       0.248   26        1
# 23                      0.263   29        1
# 31                      0.851   28        1
# 38                      0.503   27        1
# 45                      1.893   25        1
# ..                        ...  ...      ...
# 731                     0.259   22        1
# 732                     0.646   24        1
# 746                     0.358   27        1
# 750                     1.182   22        1
# 753                     0.222   26        1
#
# [84 rows x 9 columns]

# %%
# Insight 4
print(df.groupby(['Outcome'])['Age'].min())
df.groupby(['Outcome'])['Age'].max()
#  by above information we can see that female of minimum age which is 21 is suffering from 
#  Diabetes in such a young age..
#  Maybe we can Spread awareness in youngsters by advertisment or through campaigns on how we 
#  can reduce the chances of suffering from Diabetes.
# Out:
# Outcome
# 0    21
# 1    21
# Name: Age, dtype: int64
# Outcome
# 0    81
# 1    70
# Name: Age, dtype: int64

# %%
# Insight 5
# maximum pregnancies with age
df.iloc[np.where(df['Pregnancies']==17)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 159           17      163             72             41      114  40.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 159                     0.817   47        1

# %%
df['Pregnancies'].max()
# Out:
# 17

# %%
sd=df.iloc[np.where(df['Outcome']==1)]
sd=sd.iloc[np.where((sd['BloodPressure']>80)&(sd['BloodPressure']<120))]

# %%
sd=pd.DataFrame(sd)

# %%
# insight 6
sns.relplot(x='BloodPressure',y='Age',data=sd)# Of Diabetes Patients

# %%
def condition(x):
    if x<18.5:
        return "UnderWeight"
    elif x>=18.5 and x<=24.9:
        return "NormalWeight"
    elif(x>=25 and x<=29.9):
        return 'OverWeight'
    else:
        return 'Obese'
  
df['WeightType']=df['BMI'].apply(condition)

# %%
# Insight 7
df['WeightType'].value_counts()
# Out:
# Obese           472
# OverWeight      179
# NormalWeight    102
# UnderWeight      15
# Name: WeightType, dtype: int64

# %%
# insight 8
sns.catplot(x='WeightType',y='Age',data=df)
# Most of Diabetic Patients are Obese and then OverWeight

# %%
sns.relplot(x='Insulin',y='Glucose',data=df)

# %%
# insight 9
df.groupby(['WeightType'])['Outcome'].value_counts()
# Out:
# WeightType    Outcome
# NormalWeight  0           95
#               1            7
# Obese         0          253
#               1          219
# OverWeight    0          139
#               1           40
# UnderWeight   0           13
#               1            2
# Name: Outcome, dtype: int64

# %%
# insight 9
df.groupby(['WeightType'])['Pregnancies'].value_counts()
# Out:
# WeightType    Pregnancies
# NormalWeight  1              25
#               2              16
#               3              14
#               0              13
#               6               9
#               4               7
#               8               5
#               9               4
#               5               3
#               7               2
#               10              2
#               12              1
#               13              1
# Obese         0              79
#               1              72
#               2              54
#               3              45
#               4              41
#               5              38
#               7              31
#               6              26
#               8              24
#               9              21
#               10             14
#               11             10
#               13              8
#               12              5
#               14              2
#               15              1
#               17              1
# OverWeight    1              35
#               2              31
#               4              20
#               0              15
#               3              15
#               5              15
#               6              14
#               7              11
#               8               8
#               10              7
#               9               3
#               12              3
#               11              1
#               13              1
# UnderWeight   0               4
#               1               3
#               2               2
#               3               1
#               5               1
#               6               1
#               7               1
#               8               1
#               10              1
# Name: Pregnancies, dtype: int64

# %%
# insight 10
df['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome', 'WeightType'],
#       dtype='object')

# %%
df['DiabetesPedigreeFunction'].max()
# Out:
# 2.42

# %%
df['DiabetesPedigreeFunction'].min()
# Out:
# 0.078

# %%
df.iloc[np.where(df['DiabetesPedigreeFunction']==2.42)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 445            0      180             78             63       14  59.4
#
#      DiabetesPedigreeFunction  Age  Outcome WeightType
# 445                      2.42   25        1      Obese

# %%
df.iloc[445]
# Out:
# Pregnancies                     0
# Glucose                       180
# BloodPressure                  78
# SkinThickness                  63
# Insulin                        14
# BMI                          59.4
# DiabetesPedigreeFunction     2.42
# Age                            25
# Outcome                         1
# WeightType                  Obese
# Name: 445, dtype: object

# %%
sns.scatterplot(x='BMI',y='DiabetesPedigreeFunction',data=df)
# Out:
# <AxesSubplot:xlabel='BMI', ylabel='DiabetesPedigreeFunction'>

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome    WeightType
# 0                       0.627   50        1         Obese
# 1                       0.351   31        0    OverWeight
# 2                       0.672   32        1  NormalWeight
# 3                       0.167   21        0    OverWeight
# 4                       2.288   33        1         Obese
# ..                        ...  ...      ...           ...
# 763                     0.171   63        0         Obese
# 764                     0.340   27        0         Obese
# 765                     0.245   30        0    OverWeight
# 766                     0.349   47        1         Obese
# 767                     0.315   23        0         Obese
#
# [768 rows x 10 columns]

# %%
z=df.iloc[np.where((df['WeightType']=='Obese')&(df['Outcome']==1))]

# %%
z=z.iloc[np.where(z['Age']<=30)]

# %%
sns.relplot(x='Age',y='BMI',data=z)

# %%
# Diabetes Patients with 0 BloodPressure and 0 ammount of insulin Produced 
# in their body

df.iloc[np.where((df['BloodPressure']==0)& (df['Outcome']==1))]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 15             7      100              0              0        0  30.0
# 78             0      131              0              0        0  43.2
# 193           11      135              0              0        0  52.3
# 261            3      141              0              0        0  30.0
# 266            0      138              0              0        0  36.3
# 269            2      146              0              0        0  27.5
# 300            0      167              0              0        0  32.3
# 332            1      180              0              0        0  43.3
# 357           13      129              0             30        0  39.9
# 435            0      141              0              0        0  42.4
# 468            8      120              0              0        0  30.0
# 484            0      145              0              0        0  44.2
# 535            4      132              0              0        0  32.9
# 604            4      183              0              0        0  28.4
# 619            0      119              0              0        0  32.4
# 706           10      115              0              0        0   0.0
#
#      DiabetesPedigreeFunction  Age  Outcome   WeightType
# 15                      0.484   32        1        Obese
# 78                      0.270   26        1        Obese
# 193                     0.578   40        1        Obese
# 261                     0.761   27        1        Obese
# 266                     0.933   25        1        Obese
# 269                     0.240   28        1   OverWeight
# 300                     0.839   30        1        Obese
# 332                     0.282   41        1        Obese
# 357                     0.569   44        1        Obese
# 435                     0.205   29        1        Obese
# 468                     0.183   38        1        Obese
# 484                     0.630   31        1        Obese
# 535                     0.302   23        1        Obese
# 604                     0.212   36        1   OverWeight
# 619                     0.141   24        1        Obese
# 706                     0.261   30        1  UnderWeight

# %%
# For normal people Skin Thickness can't be less than 10mm
# that means people in data given below is some kind  of abnormal

df.iloc[np.where(df['SkinThickness']<=10)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 2              8      183             64              0        0  23.3
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 757            0      123             72              0        0  36.3
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 762            9       89             62              0        0  22.5
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome    WeightType
# 2                       0.672   32        1  NormalWeight
# 5                       0.201   30        0    OverWeight
# 7                       0.134   29        0         Obese
# 9                       0.232   54        1   UnderWeight
# 10                      0.191   30        0         Obese
# ..                        ...  ...      ...           ...
# 757                     0.258   52        1         Obese
# 758                     0.197   26        0         Obese
# 759                     0.278   66        1         Obese
# 762                     0.142   33        0  NormalWeight
# 766                     0.349   47        1         Obese
#
# [236 rows x 10 columns]

# %%
# BMI can't be 0.Because 0 means the person is really underweight and that is a life 
# threatning condition for the patient
w=df.iloc[np.where(df['BMI']==0)]
w.groupby(['BMI'])['Age'].value_counts()
w.iloc[np.where(w['Outcome']==1)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 9              8      125             96              0        0  0.0
# 706           10      115              0              0        0  0.0
#
#      DiabetesPedigreeFunction  Age  Outcome   WeightType
# 9                       0.232   54        1  UnderWeight
# 706                     0.261   30        1  UnderWeight

# %%
w.groupby(['BMI'])['Age'].value_counts()
# Out:
# BMI  Age
# 0.0  21     3
#      22     2
#      24     1
#      25     1
#      26     1
#      30     1
#      54     1
#      69     1
# Name: Age, dtype: int64

# %%
c=w.groupby(['BMI'])['Age'].value_counts()

# %%
sns.relplot(x='BMI',y='Age',data=c)

# %%
sns.catplot(x='WeightType',y='BMI',data=df)

# %%
# Overall Review Type
sns.set(style='darkgrid')
sns.relplot(x='BMI',y='Age',data=df,hue='WeightType',style='Outcome')

# %%
np.where(df['BMI']==0)
# Out:
# (array([  9,  49,  60,  81, 145, 371, 426, 494, 522, 684, 706], dtype=int64),)

# %%
print(df['Insulin'].min())
df['Insulin'].max()
# Out:
# 0
# 846

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df['Insulin'].median()
# Out:
# 30.5

# %%
plt.hist(df['Insulin'])
# Out:
# (array([487., 155.,  70.,  30.,   8.,   9.,   5.,   1.,   2.,   1.]),
#  array([  0. ,  84.6, 169.2, 253.8, 338.4, 423. , 507.6, 592.2, 676.8,
#         761.4, 846. ]),
#  <BarContainer object of 10 artists>)

# %%
# Patients with Diabetes having Insulin Produced more than 400.
f=df.iloc[np.where((df['Insulin']>400)& (df['Outcome']==1))]
f
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 8              2      197             70             45      543  30.5
# 13             1      189             60             23      846  30.1
# 111            8      155             62             26      495  34.0
# 186            8      181             68             36      495  30.1
# 220            0      177             60             29      478  34.6
# 370            3      173             82             48      465  38.4
# 409            1      172             68             49      579  42.4
# 415            3      173             84             33      474  35.7
# 584            8      124             76             24      600  28.7
# 655            2      155             52             27      540  38.7
# 695            7      142             90             24      480  30.4
# 753            0      181             88             44      510  43.3
#
#      DiabetesPedigreeFunction  Age  Outcome  WeightType
# 8                       0.158   53        1       Obese
# 13                      0.398   59        1       Obese
# 111                     0.543   46        1       Obese
# 186                     0.615   60        1       Obese
# 220                     1.072   21        1       Obese
# 370                     2.137   25        1       Obese
# 409                     0.702   28        1       Obese
# 415                     0.258   22        1       Obese
# 584                     0.687   52        1  OverWeight
# 655                     0.240   25        1       Obese
# 695                     0.128   43        1       Obese
# 753                     0.222   26        1       Obese

# %%
sns.relplot(x='Outcome',y='Insulin',data=f)

# %%
# Patients with Type 1 Diabetes
k=df.iloc[np.where((df['Insulin']<=100)&(df['Outcome']==1))]
k
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 6              3       78             50             32       88  31.0
# 9              8      125             96              0        0   0.0
# 11            10      168             74              0        0  38.0
# ..           ...      ...            ...            ...      ...   ...
# 754            8      154             78             32        0  32.4
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome    WeightType
# 0                       0.627   50        1         Obese
# 2                       0.672   32        1  NormalWeight
# 6                       0.248   26        1         Obese
# 9                       0.232   54        1   UnderWeight
# 11                      0.537   34        1         Obese
# ..                        ...  ...      ...           ...
# 754                     0.443   45        1         Obese
# 757                     0.258   52        1         Obese
# 759                     0.278   66        1         Obese
# 761                     0.403   43        1         Obese
# 766                     0.349   47        1         Obese
#
# [157 rows x 10 columns]

# %%
sns.relplot(x='Outcome',y='Insulin',data=k)

# %%
# These are suffering from Hyperglycemia because there glucose level 
# is high and insulin level is low.
df.iloc[np.where((df['Glucose']>=140)&(df['Insulin']<100))]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 11            10      168             74              0        0  38.0
# 22             7      196             90              0        0  39.8
# 26             7      147             76              0        0  39.4
# ..           ...      ...            ...            ...      ...   ...
# 746            1      147             94             41        0  49.3
# 749            6      162             62              0        0  24.3
# 754            8      154             78             32        0  32.4
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
#
#      DiabetesPedigreeFunction  Age  Outcome    WeightType
# 0                       0.627   50        1         Obese
# 2                       0.672   32        1  NormalWeight
# 11                      0.537   34        1         Obese
# 22                      0.451   41        1         Obese
# 26                      0.257   43        1         Obese
# ..                        ...  ...      ...           ...
# 746                     0.358   27        1         Obese
# 749                     0.178   50        1  NormalWeight
# 754                     0.443   45        1         Obese
# 759                     0.278   66        1         Obese
# 761                     0.403   43        1         Obese
#
# [97 rows x 10 columns]

# %%
# These are at border of type2 diabetes and cardiovascular diseases because 
# there glucose level and insulin level both are high.
df.iloc[np.where((df['Glucose']>=140)&(df['Insulin']>200)&(df['Outcome']==0))]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 54             7      150             66             42      342  34.7
# 95             6      144             72             27      228  33.9
# 144            4      154             62             31      284  32.8
# 153            1      153             82             42      485  40.6
# 228            4      197             70             39      744  36.7
# 247            0      165             90             33      680  52.3
# 258            1      193             50             16      375  25.9
# 286            5      155             84             44      545  38.7
# 335            0      165             76             43      255  47.9
# 364            4      147             74             25      293  34.9
# 412            1      143             84             23      310  42.4
# 487            0      173             78             32      265  46.5
# 574            1      143             86             30      330  30.1
# 608            0      152             82             39      272  41.5
# 645            2      157             74             35      440  39.4
# 710            3      158             64             13      387  31.2
#
#      DiabetesPedigreeFunction  Age  Outcome  WeightType
# 54                      0.718   42        0       Obese
# 95                      0.255   40        0       Obese
# 144                     0.237   23        0       Obese
# 153                     0.687   23        0       Obese
# 228                     2.329   31        0       Obese
# 247                     0.427   23        0       Obese
# 258                     0.655   24        0  OverWeight
# 286                     0.619   34        0       Obese
# 335                     0.259   26        0       Obese
# 364                     0.385   30        0       Obese
# 412                     1.076   22        0       Obese
# 487                     1.159   58        0       Obese
# 574                     0.892   23        0       Obese
# 608                     0.270   27        0       Obese
# 645                     0.134   30        0       Obese
# 710                     0.295   24        0       Obese

# %% [markdown]
# - In this given dataset, we haven't been informed, whether the values of glucose values has been recorded before meal or afer meal .
#
# - In this dataset "Insulin" column is not defining us about the insuline level is that Fasting reading or 30 minutes or 1 hour after glucose readings etc.
#
# - In the given Isnulin columns having 0  as value and the columns 'Outcome' having 0 as value is not possible because a person with 0 insulin amount can't be normal and it only happens when a person with suffering from diabetes Type 1.
#
# - Type 1 diabetes known as insulin-dependent diabetes, is a chronic condition in which the pancreas produces little or no insulin. Insulin is a hormone needed to allow sugar (glucose) to enter cells to produce energy.
#
# - Type 2 Diabetes is a disease marked by high glucose levels in the blood and impaired metabolism of carbohydrates, fats, and proteins, caused by the body's inability to respond effectively to insulin, combined with inadequate production of insulin by the pancreas.
#
# - These Analysis are based on best of knowledge I got from this Dataset.
