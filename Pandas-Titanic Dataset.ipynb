# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/yashw/Documents/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()/891*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
import numpy as np

# %%
a=np.array(df['Age'])
b=np.percentile(a,50)

# %%
df.drop(columns=['Cabin'],inplace=True)

# %%
df['SibSp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
c=df

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %%
df=df.set_index('PassengerId')

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
df["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Embarked']=df['Embarked'].fillna("S")

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
df[['Name','Age','Sex']]
# Out:
#                                                           Name        Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris  22.000000
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.000000
# 3                                       Heikkinen, Miss. Laina  26.000000
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.000000
# 5                                     Allen, Mr. William Henry  35.000000
# ...                                                        ...        ...
# 887                                      Montvila, Rev. Juozas  27.000000
# 888                               Graham, Miss. Margaret Edith  19.000000
# 889                   Johnston, Miss. Catherine Helen "Carrie"  29.699118
# 890                                      Behr, Mr. Karl Howell  26.000000
# 891                                        Dooley, Mr. Patrick  32.000000
#
#                 Sex
# PassengerId
# 1              male
# ...

# %%
df.groupby(['Sex'])['Age'].mean()
# Out:
# Sex
# female    28.216730
# male      30.505824
# Name: Age, dtype: float64

# %%
df.groupby(['Sex'])['Survived'].value_counts()
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Embarked     object
# dtype: object

# %%
df['Age'][889]
# Out:
# 29.69911764705882

# %%
df.groupby(['Sex'])['Sex'].value_counts()
# Out:
# Sex     Sex
# female  female    314
# male    male      577
# Name: Sex, dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
# missing = np.where(df['Age'].isnull()==True)

# %%
np.where(df['Fare']==max(df['Fare']))
# Out:
# (array([258, 679, 737], dtype=int64),)

# %%
df['Age']=df['Age'].astype(int)

# %%
df.iloc[np.where(df['Fare']==max(df['Fare']))]
# Out:
#              Survived  Pclass                                Name     Sex  \
# PassengerId
# 259                 1       1                    Ward, Miss. Anna  female
# 680                 1       1  Cardeza, Mr. Thomas Drake Martinez    male
# 738                 1       1              Lesurer, Mr. Gustave J    male
#
#              Age  SibSp  Parch    Ticket      Fare Embarked
# PassengerId
# 259           35      0      0  PC 17755  512.3292        C
# 680           36      0      1  PC 17755  512.3292        C
# 738           35      0      0  PC 17755  512.3292        C

# %%
df.iloc[np.where(df['Age']==min(df['Age'])) and np.where(df['Fare']==min(df['Fare']))]
# Out:
#              Survived  Pclass                              Name   Sex  Age  \
# PassengerId
# 180                 0       3               Leonard, Mr. Lionel  male   36
# 264                 0       1             Harrison, Mr. William  male   40
# 272                 1       3      Tornquist, Mr. William Henry  male   25
# 278                 0       2       Parkes, Mr. Francis "Frank"  male   29
# 303                 0       3   Johnson, Mr. William Cahoone Jr  male   19
# 414                 0       2    Cunningham, Mr. Alfred Fleming  male   29
# 467                 0       2             Campbell, Mr. William  male   29
# 482                 0       2  Frost, Mr. Anthony Wood "Archie"  male   29
# 598                 0       3               Johnson, Mr. Alfred  male   49
# 634                 0       1     Parr, Mr. William Henry Marsh  male   29
# 675                 0       2        Watson, Mr. Ennis Hastings  male   29
# ...

# %%
import re

# %%
df[df['Name'].str.contains("Florence")]
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 428                 1       2
# 432                 1       3
# 519                 1       2
# 707                 1       2
#
#                                                           Name     Sex  Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 428          Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female   19
# 432          Thorneycroft, Mrs. Percival (Florence Kate White)  female   29
# 519          Angle, Mrs. William A (Florence "Mary" Agnes H...  female   36
# 707                              Kelly, Mrs. Florence "Fannie"  female   45
#
#              SibSp  Parch    Ticket     Fare Embarked
# PassengerId
# 2                1      0  PC 17599  71.2833        C
# 428              0      0    250655  26.0000        S
# 432              1      0    376564  16.1000        S
# 519              1      0    226875  26.0000        S
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       891 non-null    int32
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Embarked  891 non-null    object
# dtypes: float64(1), int32(1), int64(4), object(4)
# memory usage: 105.4+ KB

# %%
df["Pclass"].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df['New Pclass']=pd.Categorical(df['Pclass'])

# %%
df['New Pclass']
# Out:
# PassengerId
# 1      3
# 2      1
# 3      3
# 4      1
# 5      3
#       ..
# 887    2
# 888    1
# 889    3
# 890    1
# 891    3
# Name: New Pclass, Length: 891, dtype: category
# Categories (3, int64): [1, 2, 3]

# %%
df.iloc[np.where(df['SibSp']>0) and np.where(df["Parch"]>0)]
# Out:
#              Survived  Pclass  \
# PassengerId
# 8                   0       3
# 9                   1       3
# 11                  1       3
# 14                  0       3
# 17                  0       3
# ...               ...     ...
# 872                 1       1
# 880                 1       1
# 881                 1       2
# 886                 0       3
# 889                 0       3
#
#                                                           Name     Sex  Age  \
# PassengerId
# 8                               Palsson, Master. Gosta Leonard    male    2
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   27
# 11                             Sandstrom, Miss. Marguerite Rut  female    4
# 14                                 Andersson, Mr. Anders Johan    male   39
# 17                                        Rice, Master. Eugene    male    2
# ...                                                        ...     ...  ...
# ...

# %%
# df['Family']=df['SibSp']+df['Parch']

# %%
df.drop(columns=['Family'])
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male   22
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 3                                       Heikkinen, Miss. Laina  female   26
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 5                                     Allen, Mr. William Henry    male   35
# ...                                                        ...     ...  ...
# ...
